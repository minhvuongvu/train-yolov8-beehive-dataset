# %% [markdown]
# <a href="https://www.kaggle.com/code/vuminhvuong/train-yolov8-beehive-dataset?scriptVersionId=179638691" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-model-yolov9-beehive-dataset/__results__.html
# /kaggle/input/train-model-yolov9-beehive-dataset/__resultx__.html
# /kaggle/input/train-model-yolov9-beehive-dataset/__notebook__.ipynb
# /kaggle/input/train-model-yolov9-beehive-dataset/__output__.json
# /kaggle/input/train-model-yolov9-beehive-dataset/custom.css
# /kaggle/input/train-model-yolov9-beehive-dataset/weights/yolov9-e-converted.pt
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/README.md
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/.git/config
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/.git/packed-refs
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/.git/HEAD
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/.git/index
# /kaggle/input/train-model-yolov9-beehive-dataset/train-yolov9-beehive-dataset/.git/description
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.9/777.9 kB 20.0 MB/s eta 0:00:00
# ...

# %%
# %cd /kaggle/working/
# !echo 'train: /kaggle/input/bee-dataset/data_Train_YOLO/train/images' >> /kaggle/working/data.yaml
# !echo 'val: /kaggle/input/bee-dataset/data_Train_YOLO/val/images' >> /kaggle/working/data.yaml
# !echo 'test: /kaggle/input/bee-dataset/data_Train_YOLO/test/images' >> /kaggle/working/data.yaml
# !echo 'nc: 1' >> /kaggle/working/data.yaml
# !echo "names: ['Bee']" >> /kaggle/working/data.yaml
# Out:
# /kaggle/working

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
# Train với CLI
# !yolo task=detect mode=train model=yolov8x.pt data=/kaggle/working/data.yaml epochs=1000 imgsz=640 batch=-1
# Out:
# ...
# 100%|█████████████████████████████████████████| 131M/131M [00:00<00:00, 325MB/s]
# Ultralytics YOLOv8.2.21 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
